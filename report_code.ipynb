# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import Union
from scipy.io import loadmat

# %% [markdown]
# # Powell's problem
#
# Given
#
# $$\boldsymbol{r}(\boldsymbol{x})=\begin{bmatrix}x_1\\ \frac{10x_1}{x_1+0.1}+2x_2^2\end{bmatrix}$$
#
# $$r_1 = x_1 = 0$$
#
# If $x_1=0$ then $r_2=2x_2^2$, which can only be $0$ if $x_2=0$
#
# Jacobian of $\boldsymbol{r}$
#
# $$J_\boldsymbol{r}=\begin{bmatrix}1 & 0\\\frac{1}{(x_1+0.1)^2}&4x_2\end{bmatrix}$$
#
# Determinant is $0$ at $(0,0)$ as such singular

# %%
X0 = np.array([3,1])

def linearLSQ(A, y):
    Q, R = np.linalg.qr(A, mode='reduced')
    x = np.linalg.solve(R, np.dot(Q.T, y))

    return x

def rJ_powell(x: Union[list, np.ndarray]):
    r = np.array([x[0], (10*x[0]) / (x[0] + 0.1) + 2*x[1]**2])
    J = np.array([[1, 0],[1 / (x[0] + 0.1) ** 2, 4*x[1]]])
    
    return r, J

r, J = rJ_powell(np.array([1,1]))
r, J
# Out:
# (array([ 1.        , 11.09090909]),
#  array([[1.        , 0.        ],
#         [0.82644628, 4.        ]]))

# %% [markdown]
# # Newton

# %%
def newton(rJ, x0, max_iter: int = 100, tol: float = 1e-10):
    max_iter *= len(x0)

    x = x0
    r, J = rJ(x)
    f = 0.5 * np.linalg.norm(r) ** 2

    stats = {
        "X": [x],
        "F": [f],
        "converged": False,
    }

    for i in range(max_iter):
        p = linearLSQ(J, r)
        x = x - p

        r, J = rJ(x)
        f = 0.5 * np.linalg.norm(r) ** 2

        stats["X"].append(x)
        stats["F"].append(f)
        if np.linalg.norm(r, np.inf) <= tol:
            stats["converged"] = True
            print("Converged")
            break
    stats["iter"] = i + 1
    return x, stats

newton_x, newton_stats = newton(rJ_powell, X0)
newton_x
# Out:
# Converged
# array([ 2.83834685e-27, -7.02404455e-06])

# %%
plt.rcParams["figure.figsize"] = 12, 6
fig, ax = plt.subplots(1, 2)

e = np.linalg.norm(newton_stats["X"], axis=1)
ax[0].plot(range(newton_stats["iter"]+1), e, label="Error")
ax[0].set_title("Error", fontsize=18)
ax[0].set_xlabel("Iterations", fontsize=16)
ax[0].set_ylabel("$e_k$", fontsize=16)


ax[1].plot(range(newton_stats["iter"]+1), newton_stats["F"], label="Function value")
ax[1].set_title("Squared norm of residuals", fontsize=18)
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_ylabel("$½||r(x_k)||_2^2$", fontsize=16)
plt.show()

# %% [markdown]
# # Gauss-Newton

# %%
import GaussNewton_line as gn_l

gauss_x, gauss_stats = gn_l.GaussNewton_line_md(rJ_powell, X0, False, maxit=newton_stats["iter"])

plt.rcParams["figure.figsize"] = 12, 6
fig, ax = plt.subplots(1, 2)
e = np.linalg.norm(gauss_stats["X"], axis=1)
ax[0].plot(range(gauss_stats["iter"]+1), e, label="Error")
ax[0].set_title("Error", fontsize=18)
ax[0].set_xlabel("Iterations", fontsize=16)
ax[0].set_ylabel("$e_k$", fontsize=16)


ax[1].plot(range(gauss_stats["iter"]+1), gauss_stats["F"], label="Function value")
ax[1].set_title("Squared norm of residuals", fontsize=18)
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_ylabel("$f(x_k)$", fontsize=16)
plt.show()

# %% [markdown]
# # Levenberg-Marquardt

# %%
def LM(func, x0, *args):
    maxit = 150 * len(x0)
    tol = 1.0e-10

    # Initial iteration
    x = np.array(x0)
    it = 0
    rx, Jx = func(x, *args)
    f = 0.5 * np.linalg.norm(rx)**2
    df = np.dot(Jx.T, rx)
    converged = (np.linalg.norm(df, np.inf) <= tol)
    nfun = 1

    # Initial lambda
    lamb = np.linalg.norm(np.dot(Jx.T, Jx))

    # Store data for plotting
    X = [x]
    F = [f]
    dF = [df]

    while not converged and it < maxit:
        it += 1
        
        A = np.vstack([Jx, np.sqrt(lamb)*np.eye(len(x))])
        b = np.hstack([-rx, np.zeros_like(x)])

        p = linearLSQ(A, b)
        
        # Update the iterate, Jacobian, residual, f, df
        x_new = x + p
        rx_new, Jx_new = func(x_new, *args)
        f_new = 0.5 * np.linalg.norm(rx_new)**2

        rho = (f - f_new) / (0.5 * np.dot(p, (lamb * p - np.dot(Jx.T, rx))))
        
        if rho > 0.75:
            lamb /= 3
        elif rho < 0.25:
            lamb *= 2
        
        # Accept or reject x_new
        if rho > 0:
            x = x_new
            rx = rx_new
            f = f_new
            Jx = Jx_new
            df = np.dot(Jx.T, rx)

        converged = (np.linalg.norm(df, np.inf) <= tol)
        nfun += 1

        # Store data for plotting
        X.append(x)
        F.append(f)
        dF.append(df)

    # Prepare return data
    if not converged:
        x = None  # Use None instead of empty for Python

    stat = {
        "converged": converged,
        "iter": it,
        "X": np.array(X),
        "F": np.array(F),
        "dF": np.array(dF),
        "nfun": nfun
    }
    
    return x, stat

LM_x, LM_stats = LM(rJ_powell, X0)

# %%
plt.rcParams["figure.figsize"] = 12, 6
fig, ax = plt.subplots(1, 2)

x_star = np.array([0,0])
e = np.linalg.norm(LM_stats["X"] - x_star, axis=1)
ax[0].plot(range(LM_stats["iter"]+1), e, label="Error")
ax[0].set_title("Error", fontsize=18)
ax[0].set_xlabel("Iterations", fontsize=16)
ax[0].set_ylabel("$e_k$", fontsize=16)

ax[1].plot(range(LM_stats["iter"]+1), LM_stats["F"], label="Function value")
ax[1].set_title("Squared norm of residuals", fontsize=18)
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_ylabel("$f(x_k)$", fontsize=16)
plt.show()

plt.plot(np.linalg.norm(LM_stats["X"] - x_star, axis=1)[1:] / np.linalg.norm(LM_stats["X"] - x_star, axis=1)[:-1], label="Relative error")
plt.legend()
plt.xlabel("Iterations", fontsize=16)
plt.ylabel("Relative error", fontsize=16)
plt.show()

# %%
import Levenberg_Marquardt_yq as LM_yq

LMyq_x, LMyq_stats = LM_yq.Levenberg_Marquardt_yq(rJ_powell, X0, 1)

fig, ax = plt.subplots(1, 2)

x_star = np.array([0,0])
e = np.linalg.norm(LMyq_stats["X"] - x_star, axis=1)
ax[0].plot(range(LMyq_stats["iter"]+1), e, label="Error")
ax[0].set_title("Error", fontsize=18)
ax[0].set_xlabel("Iterations", fontsize=16)
ax[0].set_ylabel("$e_k$", fontsize=16)

ax[1].plot(range(LMyq_stats["iter"]+1), LMyq_stats["F"], label="Function value")
ax[1].set_title("Squared norm of residuals", fontsize=18)
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_ylabel("$f(x_k)$", fontsize=16)
plt.show()

plt.plot(np.linalg.norm(LMyq_stats["X"] - x_star, axis=1)[1:] / np.linalg.norm(LMyq_stats["X"] - x_star, axis=1)[:-1], label="Relative error")
plt.legend()
plt.xlabel("Iterations", fontsize=16)
plt.ylabel("Relative error", fontsize=16)
plt.show()

# %% [markdown]
# # Change of variables

# %%
def CV_rJ_powell(x: Union[list, np.ndarray]):
    r = np.array([x[0], (10*x[0]) / (x[0] + 0.1) + 2*x[1]])
    J = np.array([[1, 0],[1 / (x[0] + 0.1) ** 2, 2]])
    
    return r, J

CV_x, CV_stats = LM_yq.Levenberg_Marquardt_yq(CV_rJ_powell, X0, tau=1e-16)

fig, ax = plt.subplots(1, 2)

x_star = np.array([0,0])
e = np.linalg.norm(CV_stats["X"] - x_star, axis=1)
ax[0].plot(range(CV_stats["iter"]+1), e, label="Error")
ax[0].set_title("Error", fontsize=18)
ax[0].set_xlabel("Iterations", fontsize=16)
ax[0].set_ylabel("$e_k$", fontsize=16)

ax[1].plot(range(CV_stats["iter"]+1), CV_stats["F"], label="Function value")
ax[1].set_title("Squared norm of residuals", fontsize=18)
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_ylabel("$f(x_k)$", fontsize=16)
plt.show()

# %% [markdown]
# ## Report plotting

# %%
plt.rcParams["figure.figsize"] = 14, 5
fig, ax = plt.subplots(1, 3)


ax[0].plot(range(gauss_stats["iter"]+1), gauss_stats["F"], label="Function value")
ax[0].set_ylabel("$f(x_k)$", fontsize=16)
ax[0].set_title("Gauss-Newton", fontsize=16)


ax[1].plot(range(LM_stats["iter"]+1), LM_stats["F"], label="Function value")
ax[1].set_xlabel("Iterations", fontsize=16)
ax[1].set_title("Levenberg-Marquardt", fontsize=16)

ax[2].plot(range(CV_stats["iter"]+1), CV_stats["F"], label="Function value")
ax[2].set_title("Change of variables", fontsize=16)

fig.suptitle("Squared norm of residuals", fontsize=22)
plt.show()

# %% [markdown]
# # Additional exercises

# %% [markdown]
# ## Rosenbrock

# %% [markdown]
# ## Linear least squares with weights

# %%
data = loadmat("data_exe3_2023.mat")
t, y = data["t"], data["y"]

# plot data
plt.scatter(t, y, color="orange")
plt.show()

A = np.block([np.exp(-27*t), np.exp(-8*t), np.ones_like(t)])

x = linearLSQ(A, y)

print(x)
x_star = np.array([1.27, 2.04, 0.3])
print(np.linalg.norm(x.flatten() - x_star))
# Out:
# [[0.77158691]
#  [2.68426325]
#  [0.23270323]]
# 0.8173246631410954

# %%
# weight matrix
W = np.diag([0.5 ** (-1)] * 10 + [0.1 ** (-1)] * (len(t) - 10))

# %%
weighted_x = linearLSQ(W@A, W@y)
print(weighted_x)
print(np.linalg.norm(weighted_x.flatten() - x_star))
# Out:
# [[1.19093158]
#  [2.27343584]
#  [0.27840347]]
# 0.24740759368436752

# %%
t_fit = np.linspace(min(t), max(t), 200)

y_fit = x[0] * np.exp(-27 * t_fit) + x[1] * np.exp(-8 * t_fit) + x[2]
weighted_y_fit = weighted_x[0] * np.exp(-27 * t_fit) + weighted_x[1] * np.exp(-8 * t_fit) + weighted_x[2]
real_fit = x_star[0] * np.exp(-27 * t_fit) + x_star[1] * np.exp(-8 * t_fit) + x_star[2]


plt.scatter(t, y, color="orange")
plt.plot(t_fit, y_fit, color="skyblue", alpha=0.7, label="Regular least squares")

plt.plot(t_fit, weighted_y_fit, color="green", alpha=0.7, label="Weighted least squares")

plt.plot(t_fit, real_fit, color="red", alpha=0.7, label="Using $x^*$")
plt.legend(fontsize=16)
plt.savefig("fit_comparison.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Solutions of linear least squares
